# %% [markdown]
# # CPS Data Project

# %% [markdown]
# ### Import packages and csv files

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

int_df = pd.read_csv('faketeacherData.csv')
count_df = pd.read_csv('teacherdatacount.csv')

# %% [markdown]
# ### Inspect datasets for datatype and no. of values

# %%
int_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2459 entries, 0 to 2458
# Data columns (total 16 columns):
# IEIN                      1336 non-null float64
# LocalTeacherID            2267 non-null object
# LastName                  2267 non-null object
# FirstName                 2267 non-null object
# BirthDate                 2267 non-null object
# SchoolYear                2459 non-null int64
# ServingLocationRCDTS      2459 non-null object
# EmployerRCDTS             2459 non-null object
# Term                      2459 non-null object
# StateCourseCode           2459 non-null object
# LocalCourseID             0 non-null float64
# LocalCourseTitle          0 non-null float64
# SectionNumber             2459 non-null object
# TeacherCourseStartDate    2267 non-null object
# EISPositionCode           2267 non-null float64
# TeacherCommitment         2267 non-null float64
# dtypes: float64(5), int64(1), object(10)
# memory usage: 307.5+ KB

# %%
count_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
# CPS School ID                  40 non-null int64
# CPS School Name                40 non-null object
# School Type                    40 non-null object
# Network                        40 non-null object
# ISBE RCDTS Code                40 non-null object
# Number of Teachers Expected    40 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 2.0+ KB

# %% [markdown]
# ### Rename TeacherDataCount Columns for easier manipulation

# %%
count_df.rename(columns={'CPS School ID':'cps_school_id',
                        'CPS School Name':'cps_school_name',
                        'School Type': 'school_type',
                        'Network': 'Network',
                        'ISBE RCDTS Code': 'isbe_rcdts_code',
                        'Number of Teachers Expected':'no_of_teachers_expected'},
                       inplace=True)

# %% [markdown]
# ### Find number of teachers submitted based on TeacherDataCount

# %%
# Find unique values
locations = count_df['isbe_rcdts_code'].unique()

# %%
# Loop through and compare number of teachers expected to number of teachers submitted for each unique rcdts code
for location in locations:
    print(location) # unique rcdts code
    print(count_df[count_df['isbe_rcdts_code']==location]['no_of_teachers_expected'].sum()) #no. of teachers expected
    print((int_df.ServingLocationRCDTS == location).sum()) # no. of teachers submitted
# Out:
# 15016299025270C
# 33
# 33
# 15016299025266C
# 34
# 34
# 15016299025268C
# 35
# 35
# 15016299025049C
# 33
# 33
# 15016299025262C
# 30
# 30
# 15016299025261C
# 32
# 32
# 15016299025085C
# 43
# 43
# 15016299025284C
# 37
# 37
# 15016299025263C
# 37
# 37
# 15016299025259C
# 40
# 2
# 15016299025267C
# 45
# 45
# 15016299025086C
# 36
# 36
# 15016299025260C
# 37
# 37
# 15016299025285C
# 45
# 45
# 15016299025264C
# 32
# 32
# 15016299025276C
# 47
# 47
# 15016299025283C
# 36
# 36
# 15016299025273C
# 42
# 207
# 15016299025109C
# 35
# 35
# 15016299025274C
# 45
# 45
# 15016299025064C
# 43
# 43
# 15016299025056C
# 41
# 41
# 15016299025057C
# 33
# 33
# 15016299025058C
# 34
# 34
# 15016299025062C
# 44
# 44
# 15016299025059C
# 78
# 78
# 15016299025073C
# 26
# 26
# 15016299025063C
# 40
# 40
# 15016299025065C
# 35
# 35
# 15016299025055C
# 42
# 42
# 15016299025066C
# 40
# 40
# 15016299025060C
# 37
# 37
# 15016299025054C
# 29
# 29
# 15016299025067C
# 35
# 35
# 15016299025068C
# 38
# 820
# 15016299025069C
# 34
# 34
# 15016299025071C
# 42
# 42
# 15016299025070C
# 41
# 41
# 15016299025072C
# 37
# 37
# 15016299025061C
# 47
# 47

# %% [markdown]
# ## Remove entries with missing mandatory info for ISBE

# %%
# Remove entries with missing teacher info in any of the following collumns 
int_df = int_df.dropna(axis=0, subset=['IEIN','LastName','FirstName','BirthDate',
                                       'SchoolYear','ServingLocationRCDTS','EmployerRCDTS',
                                       'Term','StateCourseCode','SectionNumber',
                                      'TeacherCourseStartDate','EISPositionCode','TeacherCommitment'])

# %%
# Progress check of first 50 entries
int_df.head(50)
# Out:
#         IEIN LocalTeacherID   LastName   FirstName   BirthDate  SchoolYear  \
# 0   374529.0         804678    Bernard       Jorge   11/5/1990        2019
# 2   369472.0         280726       Rios      Teagan  11/20/1971        2019
# 3   509509.0         251432     Morris        Noel   6/11/1962        2019
# 4   922488.0         303080  Fernandez   Dominique   1/20/1982        2019
# 5   689032.0         344652   Garrison    Benjamin    9/1/1974        2019
# 7    34560.0         254873    Andrews     Malcolm   1/19/1990        2019
# 9   548398.0         228275      Walls      Nathen   11/1/1964        2019
# 10  306780.0         dkelly      Kelly     Donavan   4/18/1969        2019
# 11  414712.0         352448    Cochran        Carl    4/8/1934        2019
# 13  333744.0          dbell       Bell       Devon    8/4/1962        2019
# 14  866618.0         639272      Duffy       Lamar  11/18/1970        2019
# 15  171578.0         717956       Soto      Roland   8/14/1982        2019
# 16  443020.0         460113     Dodson     Desmond    4/6/1966        2019
# 17  611044.0         652417    Daniels       Grady   3/11/1970        2019
# 21  732701.0         535618     Cortez      Dexter   8/10/1990        2019
# 30  288918.0         785030     Hanson      Konnor   9/17/1975        2019
# 31  332218.0         111114       Webb      Ismael   8/15/1965        2019
# 34  267788.0         219987      Moses       Pedro  11/15/1971        2019
# 35  948403.0         375136    Escobar      Andres   3/18/1956        2019
# 37   17392.0         179280     Conner       Asher   8/16/1967        2019
# 39  583282.0         310357     Meyers  Maximilian   5/20/1963        2019
# 41  499695.0         763300       Vang      Reagan   9/21/1981        2019
# 43  513041.0         140822    Shields       Rocco   11/2/1989        2019
# 44  450359.0         297147      Welch    Jerimiah    6/1/1977        2019
# 47  757959.0         808714    Clayton     Trystan    7/6/1969        2019
# 48  534955.0         485042     Medina        Chad    9/5/1980        2019
# 49  283239.0         549042  Castaneda       Tripp  10/14/1973        2019
# 51  279855.0     umacdonald  Macdonald      Ulises   1/14/1961        2019
# 52  970753.0         543637    Harrell       Nasir   3/12/1956        2019
# 53  221298.0         367012   Hamilton       Talan   9/16/1953        2019
# 58  617607.0         tgould      Gould       Tyree   6/19/1980        2019
# 59  168100.0          85266   Davidson     Antoine   8/10/1962        2019
# 61  580075.0         745644      Flynn        Cruz   9/18/1988        2019
# 62  592850.0         786785  Christian     Charles   7/27/1986        2019
# 63  450804.0         596126   Lawrence      Carson   5/28/1969        2019
# 65   35418.0         172316      Hanna        Luke    5/1/1990        2019
# 66  135750.0         101146    Sherman      Felipe   4/22/1951        2019
# 67  194173.0         867448      Pitts      Gunner   3/20/1956        2019
# 68  963325.0         898345    Bridges       Mateo   5/11/1989        2019
# 69   51249.0         181104     Adkins      Antwan   2/24/1957        2019
# 70  451108.0         123895      Garza        Rudy    6/2/1958        2019
# 71  792633.0          67610    Swanson       Erick  12/23/1985        2019
# 72  218932.0         740221      Cohen        Gael   10/2/1984        2019
# 75  977816.0       mandrade    Andrade       Miles    2/5/1977        2019
# 76  895419.0         177249     Mendez     Gerardo  10/25/1966        2019
# 79   37583.0         916908     Nelson        Alex   1/18/1986        2019
# 83  525917.0         472069    Fleming      Jaylan   5/19/1967        2019
# 84  759195.0         fhines      Hines      Finley   11/6/1969        2019
# 85  169120.0         660692     Branch      Kamren   9/14/1983        2019
# 86  314258.0         902461     Thomas      Felipe  10/22/1990        2019
#
#    ServingLocationRCDTS    EmployerRCDTS Term StateCourseCode  LocalCourseID  \
# 0       15016299025068C  15016299025068C   S1       04051A000            NaN
# 2       15016299025059C  15016299025059C   S1       21051A000            NaN
# 3       15016299025068C  15016299025068C   S1       02051A000            NaN
# 4       15016299025266C  15016299025266C   Y1       01001A000            NaN
# 5       15016299025068C  15016299025068C   S1       01151A000            NaN
# 7       15016299025068C  15016299025068C   S1       17101A000            NaN
# 9       15016299025059C  15016299025059C   S1       04001A000            NaN
# 10      15016299025068C  15016299025068C   S1       03101A000            NaN
# 11      15016299025276C  15016299025276C   S1       02133A000            NaN
# 13      15016299025065C  15016299025065C   Q1       01101A000            NaN
# 14      15016299025068C  15016299025068C   S1       04051A000            NaN
# 15      15016299025068C  15016299025068C   S1       16001A000            NaN
# 16      15016299025068C  15016299025068C   S1       08001A000            NaN
# 17      15016299025262C  15016299025262C   S1       02101A000            NaN
# 21      15016299025054C  15016299025054C   Y1       09151A000            NaN
# 30      15016299025068C  15016299025068C   S1       21001A000            NaN
# 31      15016299025068C  15016299025068C   Y1       12001A000            NaN
# 34      15016299025285C  15016299025285C   S1       11051A000            NaN
# 35      15016299025068C  15016299025068C   Y1       19101A000            NaN
# 37      15016299025056C  15016299025056C   S1       04051A000            NaN
# 39      15016299025068C  15016299025068C   S1       09051A000            NaN
# 41      15016299025284C  15016299025284C   S1       16051A000            NaN
# 43      15016299025260C  15016299025260C   Q1       05001A000            NaN
# 44      15016299025086C  15016299025086C   S1       19001A000            NaN
# 47      15016299025285C  15016299025285C   S1       03051A000            NaN
# 48      15016299025059C  15016299025059C   S1       02101A000            NaN
# 49      15016299025056C  15016299025056C   S1       12051A000            NaN
# 51      15016299025072C  15016299025072C   S1       01051A000            NaN
# 52      15016299025056C  15016299025056C   S1       21051A000            NaN
# 53      15016299025061C  15016299025061C   S1       20151A000            NaN
# 58      15016299025066C  15016299025066C   S1       03151A000            NaN
# 59      15016299025068C  15016299025068C   S1       02001A000            NaN
# 61      15016299025086C  15016299025086C   S1       02101A000            NaN
# 62      15016299025068C  15016299025068C   S1       19101A000            NaN
# 63      15016299025068C  15016299025068C   S1       02151A000            NaN
# 65      15016299025068C  15016299025068C   S1       06101A000            NaN
# 66      15016299025068C  15016299025068C   S1       01001A000            NaN
# 67      15016299025061C  15016299025061C   S1       01101A000            NaN
# 68      15016299025068C  15016299025068C   S1       21101A000            NaN
# 69      15016299025069C  15016299025069C   Q1       01101A000            NaN
# 70      15016299025058C  15016299025058C   S1       09101A000            NaN
# 71      15016299025049C  15016299025049C   S1       03051A000            NaN
# 72      15016299025068C  15016299025068C   S1       05001A000            NaN
# 75      15016299025259C  15016299025259C   S1       15001A000            NaN
# 76      15016299025284C  15016299025284C   S1       20051A000            NaN
# 79      15016299025068C  15016299025068C   Q1       19001A000            NaN
# 83      15016299025068C  15016299025068C   S1       01051A000            NaN
# 84      15016299025068C  15016299025068C   S1       22101A000            NaN
# 85      15016299025262C  15016299025262C   S1       01101A000            NaN
# 86      15016299025068C  15016299025068C   S1       14101A000            NaN
#
#     LocalCourseTitle                                      SectionNumber  \
# 0                NaN                             World History-Overview
# 2                NaN                             Technological Literacy
# 3                NaN                                        Pre-Algebra
# 4                NaN                English/Language Arts I (9th grade)
# 5                NaN                                    Public Speaking
# 7                NaN             Exploration of Electricity/Electronics
# 9                NaN                                    World Geography
# 10               NaN                                          Chemistry
# 11               NaN                    IB Mathematics and Computing-SL
# 13               NaN      English/Composition (freshmen and sophomores)
# 14               NaN                             World History-Overview
# 15               NaN                 Exploration of Hospitality Careers
# 16               NaN                                 Physical Education
# 17               NaN                                      Number Theory
# 21               NaN                            Air Force Junior ROTC I
# 30               NaN                         Pre-Engineering Technology
# 31               NaN                 Business/Office Career Exploration
# 34               NaN                            Audio/Visual Production
# 35               NaN                              Cosmetology-Licensing
# 37               NaN                             World History-Overview
# 39               NaN                                 Army Junior ROTC I
# 41               NaN  Exploration of Restaurant, Food and Beverage S...
# 43               NaN                                    Dance Technique
# 44               NaN                  Human Services Career Exploration
# 47               NaN                                            Biology
# 48               NaN                                      Number Theory
# 49               NaN                              Introductory Business
# 51               NaN       English/Literature (freshmen and sophomores)
# 52               NaN                             Technological Literacy
# 53               NaN                         Distribution-Comprehensive
# 58               NaN                                            Physics
# 59               NaN                               Informal Mathematics
# 61               NaN                                      Number Theory
# 62               NaN                              Cosmetology-Licensing
# 63               NaN                               General Applied Math
# 65               NaN                                          Spanish I
# 66               NaN                English/Language Arts I (9th grade)
# 67               NaN      English/Composition (freshmen and sophomores)
# 68               NaN                       Drafting Careers Exploration
# 69               NaN      English/Composition (freshmen and sophomores)
# 70               NaN                                Naval Junior ROTC I
# 71               NaN                                            Biology
# 72               NaN                                    Dance Technique
# 75               NaN              Exploration of Public Service Careers
# 76               NaN                              Truck and Bus Driving
# 79               NaN                  Human Services Career Exploration
# 83               NaN       English/Literature (freshmen and sophomores)
# 84               NaN                                         Leadership
# 85               NaN      English/Composition (freshmen and sophomores)
# 86               NaN                       Dental Laboratory Technology
#
#    TeacherCourseStartDate  EISPositionCode  TeacherCommitment
# 0              08/20/2018            201.0               1.00
# 2              01/21/2018            200.0               1.00
# 3              01/13/2018            200.0               0.36
# 4              08/20/2018            200.0               1.00
# 5              08/20/2018            200.0               1.00
# 7              08/20/2018            205.0               1.00
# 9               8/20/2018            200.0               1.00
# 10             08/20/2018            200.0               1.00
# 11             08/20/2018            200.0               1.00
# 13             02/10/2018            200.0               1.00
# 14             02/11/2018            200.0               1.00
# 15             08/20/2018            200.0               1.00
# 16             08/20/2018            200.0               1.00
# 17             08/20/2018            201.0               1.00
# 21             08/20/2018            200.0               1.00
# 30             01/23/2018            200.0               1.00
# 31             08/18/2018            200.0               1.00
# 34             02/01/2018            200.0               1.00
# 35             02/25/2018            200.0               1.00
# 37             02/16/2018            200.0               1.00
# 39             08/20/2018            200.0               1.00
# 41             01/14/2018            200.0               1.00
# 43             08/20/2018            200.0               1.00
# 44             01/26/2018            200.0               1.00
# 47             08/20/2018            200.0               1.00
# 48             08/20/2018            200.0               1.00
# 49             08/20/2018            200.0               1.00
# 51             09/18/2018            200.0               1.00
# 52             08/08/2018            203.0               1.00
# 53             08/05/2018            200.0               1.00
# 58             08/20/2018            200.0               1.00
# 59             08/20/2018            204.0               1.00
# 61             08/20/2018            200.0               1.00
# 62             02/13/2018            200.0               1.00
# 63             09/21/2018            201.0               1.00
# 65             08/20/2018            205.0               1.00
# 66             08/20/2018            200.0               1.00
# 67             08/20/2018            200.0               1.00
# 68             08/20/2018            205.0               1.00
# 69             08/20/2018            200.0               1.00
# 70             08/20/2018            200.0               1.00
# 71             08/05/2018            200.0               1.00
# 72             08/18/2018            200.0               1.00
# 75             09/12/2018            200.0               1.00
# 76             08/20/2018            200.0               1.00
# 79             08/20/2018            200.0               1.00
# 83             08/20/2018            200.0               1.00
# 84             02/28/2018            200.0               1.00
# 85             08/20/2018            200.0               1.00
# 86             08/20/2018            200.0               1.00

# %% [markdown]
# ### Remove nonnumeric values from TeacherID

# %%
int_df = int_df[int_df['LocalTeacherID'].apply(lambda x: str(x).isdigit())]

# %%
# Confirm values are correct
int_df['LocalTeacherID'].unique()
# Out:
# array(['804678', '280726', '251432', ..., '46538', '760249', '70447'],
#       dtype=object)

# %% [markdown]
# ### Fix Date format

# %%
# Use standard date
int_df['BirthDate'] = pd.to_datetime(int_df['BirthDate'])
int_df['BirthDate'] = int_df['BirthDate'].dt.strftime('%m/%d/%Y')
int_df['TeacherCourseStartDate'] = pd.to_datetime(int_df['TeacherCourseStartDate'])
int_df['TeacherCourseStartDate'] = int_df['TeacherCourseStartDate'].dt.strftime('%m/%d/%Y')

# %% [markdown]
# ### Remove values for Term that aren't included in ISBE list

# %%
int_df = int_df[int_df['Term'].str.len() >= 2]

# %%
# confirm unique values for Term are ISBE appropriate
int_df['Term'].unique()
# Out:
# array(['S1', 'Y1', 'Q1'], dtype=object)

# %%
int_df.head()
# Out:
#        IEIN LocalTeacherID   LastName  FirstName   BirthDate  SchoolYear  \
# 0  374529.0         804678    Bernard      Jorge  11/05/1990        2019
# 2  369472.0         280726       Rios     Teagan  11/20/1971        2019
# 3  509509.0         251432     Morris       Noel  06/11/1962        2019
# 4  922488.0         303080  Fernandez  Dominique  01/20/1982        2019
# 5  689032.0         344652   Garrison   Benjamin  09/01/1974        2019
#
#   ServingLocationRCDTS    EmployerRCDTS Term StateCourseCode  LocalCourseID  \
# 0      15016299025068C  15016299025068C   S1       04051A000            NaN
# 2      15016299025059C  15016299025059C   S1       21051A000            NaN
# 3      15016299025068C  15016299025068C   S1       02051A000            NaN
# 4      15016299025266C  15016299025266C   Y1       01001A000            NaN
# 5      15016299025068C  15016299025068C   S1       01151A000            NaN
#
#    LocalCourseTitle                        SectionNumber  \
# 0               NaN               World History-Overview
# 2               NaN               Technological Literacy
# 3               NaN                          Pre-Algebra
# 4               NaN  English/Language Arts I (9th grade)
# 5               NaN                      Public Speaking
#
#   TeacherCourseStartDate  EISPositionCode  TeacherCommitment
# 0             08/20/2018            201.0               1.00
# 2             01/21/2018            200.0               1.00
# 3             01/13/2018            200.0               0.36
# 4             08/20/2018            200.0               1.00
# 5             08/20/2018            200.0               1.00

# %% [markdown]
# ### Check EISPosition to make sure they are ISBE appropriate

# %%
# Position codes from ISBE form
position_codes = [200,201,202,203,204,207,208,250,
                  251,310,601,602,603,604,605,606,
                  607,608,609,610,611,699]

# %%
# Unique position codes from TeacherData
p_codes = int_df['EISPositionCode'].unique()
print(p_codes)
# Out:
# [201. 200. 205. 203. 204. 202.]

# %%
# Remove position codes that equal 205
int_df =int_df[int_df['EISPositionCode']!=205]

# %%
# Confirm position codes
int_df['EISPositionCode'].unique()
# Out:
# array([201., 200., 203., 204., 202.])

# %% [markdown]
# ### Evaluate StateCourseCode and make sure compliant with ISBE

# %%
int_df['StateCourseCode'].unique()
# Out:
# array(['04051A000', '21051A000', '02051A000', '01001A000', '01151A000',
#        '04001A000', '02133A000', '16001A000', '08001A000', '02101A000',
#        '09151A000', '21001A000', '12001A000', '11051A000', '19101A000',
#        '09051A000', '16051A000', '05001A000', '19001A000', '03051A000',
#        '12051A000', '20151A000', '02001A000', '02151A000', '01101A000',
#        '09101A000', '20051A000', '01051A000', '14101A000', '18149A000',
#        '03101A000', '05148A000', '15001A000', '15051A000', '02049A000',
#        '14151A000', '18101A000', '16101A000', '05101A000', '04151A000',
#        '03151A000', '11101A000', '03049A000', '08051A000', '18051A000',
#        '10051A000', '03001A000', '04149A000', '04101A000', '01148A000',
#        '05051A000', '15151A000', '10151A000', '22101A000', '22051A000',
#        '05151A000', '10101A000', '17051A000', '20001A000', '09001A000',
#        '22001A000', '08151A000', '15147A000', '02141A000', '17048A000',
#        '19051A000', '18001A000', '06101A000', '15101A000', '17001A000',
#        '10001A000', '22151A000', '19151A000', '16151A000', '14051A000',
#        '21101A000', '19101A001', '12151A000', '13149A000', '06133A000',
#        '13101A000', '17101A000', '04048A000', '06146A000', '07001A000',
#        '06151A000', '03001A001', '04147A000', '16147A000', '01051Å000',
#        '13001A000', '11151A000', '20101A000', '06141A000', '06148A000',
#        '17148A000', '02131A000', '12101A000', '14001A000', '12001Å000',
#        '03148A000', '01149A000', '04148A000', '16148A000', '04047A000',
#        '03149A000', '03048A000', '18148A000', '09101Å000', '03147A000',
#        '21048A000', '06145A000', '02132A000', '02134A000', '14147A000'],
#       dtype=object)

# %%
# Check first two string values to make sure they match ISBE Course Codes
int_df[(int_df['StateCourseCode']).str.startswith('04')]['SectionNumber'].unique()
# Out:
# array(['World History-Overview', 'World Geography',
#        'U.S. Government-Comprehensive', 'U.S. History-Other',
#        'U.S. History-Comprehensive', 'Geography-Workplace Experience',
#        'U.S. History-Independent Study',
#        'U.S. History-Workplace Experience', 'Geography-Independent Study'],
#       dtype=object)

# %% [markdown]
# ### Add Network Column to dataset

# %%
# Rename column for merge function
count_df = count_df.rename(columns={"isbe_rcdts_code": "ServingLocationRCDTS"})

# %%
# Merge datasets on ServingLocationRCDTS (like Vlookup)
int_df = pd.merge(int_df,count_df[['ServingLocationRCDTS','Network']],on='ServingLocationRCDTS', how='left')

# %% [markdown]
# ### Drop Empy Columns

# %%
int_df = int_df.drop(columns=['LocalCourseID','LocalCourseTitle'])

# %% [markdown]
# ### Export to CSV

# %%
int_df.to_csv('isbe.csv')
